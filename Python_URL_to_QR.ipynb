# %% [markdown]
# <a href="https://colab.research.google.com/github/singhudaypratap/pythonURL2QR/blob/main/Python_URL_to_QR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## QR GENERATOR

# %%
# Install Libraries
# !pip install Pillow
# !pip install qrcode
# import ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 810 kB/s
# ...
#   Created wheel for qrcode: filename=qrcode-7.3.1-py3-none-any.whl size=40402 sha256=1320548615a95ae05618f996eff5b1e1dc629d798c9071045c13f0c2bdb41aa5
#   Stored in directory: /root/.cache/pip/wheels/93/d7/39/a4111be2cfb8e679938aa671a37888b6afb1f9e7d748e94492
# Successfully built qrcode
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c44b04b6-92d9-471e-9157-52a3dc380270" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c44b04b6-92d9-471e-9157-52a3dc380270">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving piet_logo.jpg to piet_logo.jpg

# %%
img_url='/content/piet_logo.jpg'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
img=plt.imread(img_url)
plt.imshow(img)
plt.grid(None)
plt.show()

# %%
# import modules
import qrcode
from PIL import Image
# taking image which user wants
# in the QR code center
Logo_link = 'piet_logo.jpg'

url = input("Enter your  URL Here")

logo = Image.open(Logo_link)
basewidth = 100
# adjust image size
wpercent = (basewidth/float(logo.size[0]))
hsize = int((float(logo.size[1])*float(wpercent)))
logo = logo.resize((basewidth, hsize), Image.ANTIALIAS)
QRcode = qrcode.QRCode(error_correction=qrcode.constants.ERROR_CORRECT_H)
QRcode.add_data(url)
QRcode.make()
# Assigning color
QRcolor = '#006400'
QRimg = QRcode.make_image(fill_color=QRcolor, back_color="white").convert('RGB')
 
# set size of QR code
pos = ((QRimg.size[0] - logo.size[0]) // 2,
       (QRimg.size[1] - logo.size[1]) // 2)
QRimg.paste(logo, pos)
 
# save the QR code generated
QRimg.save('project_QR.png')
x=plt.imread('project_QR.png', format= "png")
plt.imshow(x)
plt.grid(None)
# Out:
# Enter your  URL Herehttp://www.piet.poornima.org/
